# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://web.archive.org/web/20220101112945/http://ippan.org.np/ippan-members"

# Make a GET request to the specified URL
response = requests.get(url)

#check that HTML works
if response.status_code == 200:
    #print the html content of the page
    print(response.text)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><script type="text/javascript" src="https://web-static.archive.org/_static/js/bundle-playback.js?v=t1Bf4PY_" charset="utf-8"></script>
# <script type="text/javascript" src="https://web-static.archive.org/_static/js/wombat.js?v=txqj7nKC" charset="utf-8"></script>
# <script>window.RufflePlayer=window.RufflePlayer||{};window.RufflePlayer.config={"autoplay":"on","unmuteOverlay":"hidden"};</script>
# <script type="text/javascript" src="https://web-static.archive.org/_static/js/ruffle/ruffle.js"></script>
# <script type="text/javascript">
#   __wm.init("https://web.archive.org/web");
#   __wm.wombat("http://ippan.org.np/ippan-members","20220101112945","https://web.archive.org/","web","https://web-static.archive.org/_static/",
# 	      "1641036585");
# </script>
# <link rel="stylesheet" type="text/css" href="https://web-static.archive.org/_static/css/banner-styles.css?v=S1zqJCYt" />
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://web.archive.org/web/20220101112945/http://ippan.org.np/ippan-members"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #Find all sections containing company information
    company_sections = soup.find_all('div', class_='card-body')

    #Loop through each company section
    for company_section in company_sections:
        
        company_info = {}
        
        spans = company_section.find_all('span', style='background-color:#99ffff')

        for span in spans:
            # Extract field name from the <strong> tag
            field_name = span.find('strong')
            if field_name:
                field_name = field_name.get_text().strip().rstrip(':')
                # Extract the value, removing the field name part
                value = span.get_text().replace(field_name, '', 1).strip().strip('"')
                company_info[field_name] = value
                        
            
        # Print the extracted information for each company
        for field, value in company_info.items():
            print(f"{field}: {value}")

        print("===")  # Separating information for different companies
    
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ===
# Name: : Himal Power Limited
# Address: : Jhamsikhel, Sanepa
# Contact Person: : Sunil Manandhar
# Title: : Project Development Manager
# Category: : Corporate
# Name of Project: : Khimti
# Capacity: : 60MW
# Status: : Operation
# Location: : Kirne, Dolkha
# Tel/Fax: : 5521864/ 5536411
# Email: sunil.manandhar@hpl.com.np:
# ===
# Name: : Bhote Koshi Power Co. Pvt. Ltd.
# Address: : Tahachal, Kathmandu
# Contact Person: : Bikram R. Staphit
# Title: : Chief Executive Officer
# Category: : Corporate
# Name of Project: :  Bhote Koshi
# Capacity: :45 MW (36MW+9MW)
# Status: : Forced Outage (from April 25, 2015 due to earthquake)
# Location: : Sindhupalchowk
# Telephone: : 5902508/09
# Email: bikram.sthapit@bkpc.com.np:
# ===
# ===
# ===
# ===
# Name: : Panchakanya Mai Hydropower Ltd.
# Address: : Pulchowk, Lalitpur
# Contact Person: : BholaBhola Nath Upadhyay
# Title: : Managing Director
# Category: :
# Name of Project: : Upper Mai HEP
# Capacity: : 9.98 MW
# Status: : Operation
# ...
